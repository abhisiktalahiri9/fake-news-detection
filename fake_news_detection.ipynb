# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import string
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
data_fake=pd.read_csv('Fake.csv')
data_true=pd.read_csv('True.csv')

# %%
data_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
data_true.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
data_fake["class"]=0
data_true['class']=1

# %%
data_fake.shape, data_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
data_fake_manual_testing = data_fake.tail(10)
for i in range(23480,23470,-1):
    data_fake.drop([i],axis = 0, inplace = True)

    
data_true_manual_testing = data_true.tail(10)
for i in range(21416,21406,-1):
    data_true.drop([i],axis = 0, inplace = True)

# %%
data_fake.shape, data_true.shape
# Out:
# ((23471, 5), (21407, 5))

# %%
data_fake_manual_testing['class']=0
data_true_manual_testing['class']=1
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_18848\1676563180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_fake_manual_testing['class']=0
# C:\Users\Acer\AppData\Local\Temp\ipykernel_18848\1676563180.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_true_manual_testing['class']=1

# %%
data_fake_manual_testing.head(10)
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# ...

# %%
data_true_manual_testing.head(10)
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# ...

# %%
data_merge=pd.concat([data_fake, data_true], axis = 0)
data_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
data_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
data=data_merge.drop(['title','subject','date'], axis = 1)

# %%
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
data = data.sample(frac = 1)

# %%
data.head()
# Out:
#                                                     text  class
# 21303  SAMARKAND, Uzbekistan (Reuters) - Lola Karimov...      1
# 20985  GENEVA (Reuters) - Beijing is waging a campaig...      1
# 17640  After reporter and model, Leeann Tweeden accus...      0
# 10770  There was a heavy push and big-time lobbying f...      0
# 1830   At this point in Trump s disastrous presidency...      0

# %%
data.reset_index(inplace = True)
data.drop(['index'], axis = 1,inplace = True)

# %%
data.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
data.head()
# Out:
#                                                 text  class
# 0  SAMARKAND, Uzbekistan (Reuters) - Lola Karimov...      1
# 1  GENEVA (Reuters) - Beijing is waging a campaig...      1
# 2  After reporter and model, Leeann Tweeden accus...      0
# 3  There was a heavy push and big-time lobbying f...      0
# 4  At this point in Trump s disastrous presidency...      0

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]','',text)
    text = re.sub("\\W"," ",text)
    text = re.sub('https?://\S+|www\.\S+','',text)
    text = re.sub('<.*?>+',b'',text)
    text = re.sub('[%s]' % re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Acer\AppData\Local\Temp\ipykernel_21972\3761340717.py:3: SyntaxWarning: invalid escape sequence '\['
#   text = re.sub('\[.*?\]','',text)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_21972\3761340717.py:5: SyntaxWarning: invalid escape sequence '\S'
#   text = re.sub('https?://\S+|www\.\S+','',text)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_21972\3761340717.py:8: SyntaxWarning: invalid escape sequence '\w'
#   text = re.sub('\w*\d\w*','',text)

# %%
data['text'] = data['text'].apply(wordopt)

# %%
x = data['text']
y = data['class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9833333333333333

# %%
print (classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      5911
#            1       0.98      0.98      0.98      5309
#
#     accuracy                           0.98     11220
#    macro avg       0.98      0.98      0.98     11220
# weighted avg       0.98      0.98      0.98     11220

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score(xv_test, y_test)
# Out:
# 0.9967023172905526

# %%
print (classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      5911
#            1       0.98      0.98      0.98      5309
#
#     accuracy                           0.98     11220
#    macro avg       0.98      0.98      0.98     11220
# weighted avg       0.98      0.98      0.98     11220

# %%
from sklearn.ensemble import GradientBoostingClassifier

GB = GradientBoostingClassifier(random_state = 0)
GB.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gb = GB.predict(xv_test)

# %%
GB.score(xv_test, y_test)
# Out:
# 0.9953654188948307

# %%
print(classification_report(y_test, pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5911
#            1       0.99      1.00      1.00      5309
#
#     accuracy                           1.00     11220
#    macro avg       1.00      1.00      1.00     11220
# weighted avg       1.00      1.00      1.00     11220

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(random_state = 0)
RF.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rf = RF.predict(xv_test)

# %%
RF.score(xv_test, y_test)
# Out:
# 0.9880570409982175

# %%
print (classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      5911
#            1       0.98      0.98      0.98      5309
#
#     accuracy                           0.98     11220
#    macro avg       0.98      0.98      0.98     11220
# weighted avg       0.98      0.98      0.98     11220

# %%
def output_lable(n):
    if n==0:
        return "Fake News"
    elif n==1:
        return "Not A Fake News"
    
def manual_testing(news):
    testing_news = {"text":[news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test['text'] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_GB = GB.predict(new_xv_test)
    pred_RF = RF.predict(new_xv_test)
    
    return print("\n\nLR Predicition: {} \nDT Prediction: {} \nGBC Prediction: {} \nRFC Prediction:{}".format(output_lable(pred_LR[0]),
                                                                                                             output_lable(pred_DT[0]),
                                                                                                             output_lable(pred_GB[0]),
                                                                                                             output_lable(pred_RF[0])))

# %%
news = str(input()) 
manual_testing(news)
# Out:
# LR Predicition: Fake News
# DT Prediction: Fake News
# GBC Prediction: Fake News
# RFC Prediction:Fake News

# %%
from pathlib import Path
import nbformat

# Load the notebook
notebook_path = Path("fake_news_detection.ipynb")
with notebook_path.open() as f:
    notebook = nbformat.read(f, as_version=4)

# Extract code cells
code_cells = [cell['source'] for cell in notebook.cells if cell.cell_type == 'code']
code_cells[:5]  # Show the first few code cells for context
# Out:
# ['import pandas as pd\nimport matplotlib.pyplot as plt\nimport numpy as np\nimport seaborn as sns\nimport string\nimport re\nfrom sklearn.model_selection import train_test_split\nfrom sklearn.metrics import accuracy_score\nfrom sklearn.metrics import classification_report',
#  "data_fake=pd.read_csv('Fake.csv')\ndata_true=pd.read_csv('True.csv')",
#  'data_fake.head()',
#  'data_true.tail()',
#  'data_fake["class"]=0\ndata_true[\'class\']=1']

# %%
# Search for model and vectorizer definitions in the notebook code
model_keywords = ["LogisticRegression", "DecisionTreeClassifier", "RandomForestClassifier", "GradientBoostingClassifier"]
vectorizer_keywords = ["TfidfVectorizer", "CountVectorizer"]

# Look for lines that create these objects
model_lines = []
vectorizer_lines = []
for cell in code_cells:
    for line in cell.splitlines():
        if any(keyword in line for keyword in model_keywords):
            model_lines.append(line)
        if any(keyword in line for keyword in vectorizer_keywords):
            vectorizer_lines.append(line)

model_lines, vectorizer_lines
# Out:
# (['from sklearn.linear_model import LogisticRegression',
#   'LR = LogisticRegression()',
#   'from sklearn.tree import DecisionTreeClassifier',
#   'DT = DecisionTreeClassifier()',
#   'from sklearn.ensemble import GradientBoostingClassifier',
#   'GB = GradientBoostingClassifier(random_state = 0)',
#   'from sklearn.ensemble import RandomForestClassifier',
#   'RF = RandomForestClassifier(random_state = 0)'],
#  ['from sklearn.feature_extraction.text import TfidfVectorizer',
#   'vectorization = TfidfVectorizer()'])

# %%
import pickle

# Save the trained model (change 'RF' if you used a different one)
with open("model.pkl", "wb") as model_file:
    pickle.dump(RF, model_file)

# Save the vectorizer
with open("vectorizer.pkl", "wb") as vec_file:
    pickle.dump(vectorization, vec_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 9
#       7 # Save the vectorizer
#       8 with open("vectorizer.pkl", "wb") as vec_file:
# ----> 9     pickle.dump(vectorization, vec_file)
#
# NameError: name 'vectorization' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 from sklearn.feature_extraction.text import TfidfVectorizer
# ----> 2 xv_train = vectorization.fit_transform(x_train)
#
# NameError: name 'x_train' is not defined

# %%
# Let's scan the notebook for where RF (RandomForestClassifier) might have been trained or fitted
rf_training_cells = [cell for cell in code_cells if 'RF' in cell and ('fit' in cell or '=' in cell)]
rf_training_cells
# Out:
# ['from sklearn.ensemble import RandomForestClassifier\n\nRF = RandomForestClassifier(random_state = 0)\nRF.fit(xv_train, y_train)',
#  'pred_rf = RF.predict(xv_test)',
# ...

# %%
# Search for any cells that show how 'vectorization' was used or trained
vectorizer_usage_cells = [cell for cell in code_cells if 'vectorization' in cell]
vectorizer_usage_cells
# Out:
# ['from sklearn.feature_extraction.text import TfidfVectorizer\n\nvectorization = TfidfVectorizer()\nxv_train = vectorization.fit_transform(x_train)\nxv_test = vectorization.transform(x_test)',
# ...
